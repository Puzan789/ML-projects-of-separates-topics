# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
df_train,df_test=train_test_split(df,test_size=0.4,random_state=34)

# %%
x=df_train.iloc[:,:-1]
y=df_train.iloc[:,-1:]

# %%
regressor=LinearRegression()
regressor.fit(x,y)
# Out:
# LinearRegression()

# %%
pred=df_test.iloc[123:124]
pred=pred.drop('Outcome',axis=1)

# %%
regressor.predict(pred)
# Out:
# array([[0.19661413]])

# %%
y_test=df_test[['Outcome']].values
x_test=df_test.drop("Outcome",axis=1).values

# %%
for i in range (len(y_test)):
    print("actual outcome",y_test[i][0],"predicted:",round(regressor.predict(x_test)[i][0]))
# Out:
# actual outcome 0 predicted: 0
# actual outcome 0 predicted: 0
# actual outcome 1 predicted: 1
# actual outcome 0 predicted: 0
# actual outcome 0 predicted: 0
# actual outcome 0 predicted: 0
# actual outcome 1 predicted: 0
# actual outcome 0 predicted: 0
# actual outcome 1 predicted: 0
# actual outcome 1 predicted: 1
# actual outcome 0 predicted: 0
# actual outcome 0 predicted: 0
# actual outcome 1 predicted: 0
# actual outcome 0 predicted: 0
# actual outcome 0 predicted: 0
# actual outcome 0 predicted: 0
# actual outcome 1 predicted: 1
# actual outcome 0 predicted: 1
# actual outcome 1 predicted: 1
# actual outcome 0 predicted: 0
# actual outcome 1 predicted: 0
# actual outcome 0 predicted: 0
# actual outcome 0 predicted: 0
# actual outcome 0 predicted: 1
# actual outcome 0 predicted: 0
# actual outcome 1 predicted: 0
# actual outcome 1 predicted: 0
# actual outcome 0 predicted: 0
# actual outcome 0 predicted: 0
# actual outcome 1 predicted: 0
# actual outcome 0 predicted: 0
# ...

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,regressor.predict(x_test))
# Out:
# C:\Users\puzan12\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 0.2918942935463775

# %% [markdown]
# - evaluation shows that  means that 29.19% of the differences in the data points from their average can be understood or predicted by the factors (independent variables) in the model. The remaining 70.81% of the differences are not explained by the model and might be due to factors that were not considered or random chance.
