# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# - simple linear regression is a type of regression algorithms that models the relationship between single dependent and independent variables

# %%
data=pd.read_csv("Salary_dataset.csv")
data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
X = data[['YearsExperience']]
y = data['Salary']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pre = regressor.predict(np.array([[5]]))
y_pre
# Out:
# C:\Users\puzan12\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([72612.31021533])

# %%
y_pred=regressor.predict(X_test)

# %%
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),color="blue")

# %%
plt.scatter(X_test,y_test,color='red')
plt.plot(X_train,regressor.predict(X_train),color="blue")
