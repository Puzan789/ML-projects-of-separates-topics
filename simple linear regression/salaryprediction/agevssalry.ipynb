# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('Sd.csv',usecols=['Age','Salary'])

# %%
df.dropna(inplace=True)

# %%
X=df.iloc[:,0:-1].values
y=df.iloc[:,-1:].values

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.3,random_state=30)

# %%
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
imp=int(input("enter your age"))
print("Your salary is :",regressor.predict(np.array([[imp]]))[0][0])
# Out:
# enter your age56
# Your salary is : 220284.30443486362

# %%
predicted=regressor.predict(X_test)
for i in range(len(X_test)):
    print("age:",X_test[i][0],"predicted value :",predicted[i][0],"real_value:",Y_test[i][0])
# Out:
# age: 31.0 predicted value : 59480.23674370843 real_value: 60000.0
# age: 47.0 predicted value : 162394.84006604773 real_value: 170000.0
# age: 24.0 predicted value : 14455.097790184955 real_value: 40000.0
# age: 31.0 predicted value : 59480.23674370843 real_value: 45000.0
# age: 26.0 predicted value : 27319.42320547739 real_value: 40000.0
# age: 38.0 predicted value : 104505.37569723188 real_value: 80000.0
# age: 35.0 predicted value : 85208.88757429327 real_value: 95000.0
# age: 33.0 predicted value : 72344.56215900084 real_value: 50000.0
# age: 33.0 predicted value : 72344.56215900084 real_value: 115000.0
# age: 40.0 predicted value : 117369.70111252432 real_value: 80000.0
# age: 36.0 predicted value : 91641.05028193948 real_value: 60000.0
# age: 33.0 predicted value : 72344.56215900084 real_value: 60000.0
# age: 34.0 predicted value : 78776.72486664704 real_value: 95000.0
# age: 35.0 predicted value : 85208.88757429327 real_value: 110000.0
# age: 31.0 predicted value : 59480.23674370843 real_value: 50000.0
# age: 50.0 predicted value : 181691.3281889864 real_value: 160000.0
# age: 23.0 predicted value : 8022.935082538752 real_value: 35000.0
# age: 36.0 predicted value : 91641.05028193948 real_value: 95000.0
# age: 35.0 predicted value : 85208.88757429327 real_value: 85000.0
# age: 37.0 predicted value : 98073.21298958568 real_value: 100000.0
# age: 26.0 predicted value : 27319.42320547739 real_value: 35000.0
# age: 28.0 predicted value : 40183.748620769795 real_value: 40000.0
# age: 34.0 predicted value : 78776.72486664704 real_value: 105000.0
# age: 35.0 predicted value : 85208.88757429327 real_value: 85000.0
# age: 27.0 predicted value : 33751.58591312359 real_value: 45000.0
# age: 38.0 predicted value : 104505.37569723188 real_value: 120000.0
# age: 44.0 predicted value : 143098.35194310913 real_value: 130000.0
# age: 41.0 predicted value : 123801.86382017052 real_value: 90000.0
# age: 31.0 predicted value : 59480.23674370843 real_value: 50000.0
# age: 37.0 predicted value : 98073.21298958568 real_value: 120000.0
# age: 44.0 predicted value : 143098.35194310913 real_value: 110000.0
# age: 50.0 predicted value : 181691.3281889864 real_value: 130000.0
# age: 40.0 predicted value : 117369.70111252432 real_value: 100000.0
# age: 29.0 predicted value : 46615.911328416 real_value: 75000.0
# age: 35.0 predicted value : 85208.88757429327 real_value: 85000.0
# age: 30.0 predicted value : 53048.07403606223 real_value: 50000.0
# age: 33.0 predicted value : 72344.56215900084 real_value: 70000.0
# age: 30.0 predicted value : 53048.07403606223 real_value: 50000.0
# age: 32.0 predicted value : 65912.39945135463 real_value: 65000.0
# age: 31.0 predicted value : 59480.23674370843 real_value: 55000.0
# age: 41.0 predicted value : 123801.86382017052 real_value: 150000.0
# age: 42.0 predicted value : 130234.02652781672 real_value: 120000.0
# age: 40.0 predicted value : 117369.70111252432 real_value: 130000.0
# age: 40.0 predicted value : 117369.70111252432 real_value: 130000.0
# age: 30.0 predicted value : 53048.07403606223 real_value: 45000.0
# age: 38.0 predicted value : 104505.37569723188 real_value: 110000.0
# age: 35.0 predicted value : 85208.88757429327 real_value: 85000.0
# age: 47.0 predicted value : 162394.84006604773 real_value: 160000.0
# age: 42.0 predicted value : 130234.02652781672 real_value: 120000.0
# age: 37.0 predicted value : 98073.21298958568 real_value: 90000.0
# age: 51.0 predicted value : 188123.4908966326 real_value: 170000.0
# age: 33.0 predicted value : 72344.56215900084 real_value: 65000.0
# age: 42.0 predicted value : 130234.02652781672 real_value: 100000.0
# age: 33.0 predicted value : 72344.56215900084 real_value: 60000.0
# age: 40.0 predicted value : 117369.70111252432 real_value: 110000.0
# age: 47.0 predicted value : 162394.84006604773 real_value: 200000.0
# age: 44.0 predicted value : 143098.35194310913 real_value: 150000.0
# age: 36.0 predicted value : 91641.05028193948 real_value: 95000.0
# age: 50.0 predicted value : 181691.3281889864 real_value: 180000.0
# age: 31.0 predicted value : 59480.23674370843 real_value: 45000.0
# age: 45.0 predicted value : 149530.51465075533 real_value: 140000.0
# age: 48.0 predicted value : 168827.00277369394 real_value: 170000.0
# age: 46.0 predicted value : 155962.67735840153 real_value: 150000.0
# age: 29.0 predicted value : 46615.911328416 real_value: 45000.0
# age: 47.0 predicted value : 162394.84006604773 real_value: 190000.0
# age: 33.0 predicted value : 72344.56215900084 real_value: 50000.0
# age: 43.0 predicted value : 136666.18923546292 real_value: 105000.0
# age: 37.0 predicted value : 98073.21298958568 real_value: 95000.0
# age: 37.0 predicted value : 98073.21298958568 real_value: 95000.0
# age: 30.0 predicted value : 53048.07403606223 real_value: 45000.0
# age: 35.0 predicted value : 85208.88757429327 real_value: 65000.0
# age: 35.0 predicted value : 85208.88757429327 real_value: 105000.0
# age: 50.0 predicted value : 181691.3281889864 real_value: 160000.0
# age: 43.0 predicted value : 136666.18923546292 real_value: 140000.0
# age: 39.0 predicted value : 110937.53840487808 real_value: 115000.0
# age: 41.0 predicted value : 123801.86382017052 real_value: 120000.0
# age: 48.0 predicted value : 168827.00277369394 real_value: 180000.0
# age: 48.0 predicted value : 168827.00277369394 real_value: 170000.0
# age: 36.0 predicted value : 91641.05028193948 real_value: 85000.0
# age: 51.0 predicted value : 188123.4908966326 real_value: 185000.0
# age: 31.0 predicted value : 59480.23674370843 real_value: 45000.0
# age: 36.0 predicted value : 91641.05028193948 real_value: 120000.0
# age: 51.0 predicted value : 188123.4908966326 real_value: 190000.0
# age: 26.0 predicted value : 27319.42320547739 real_value: 45000.0
# age: 47.0 predicted value : 162394.84006604773 real_value: 180000.0
# age: 27.0 predicted value : 33751.58591312359 real_value: 45000.0
# age: 44.0 predicted value : 143098.35194310913 real_value: 130000.0
# age: 28.0 predicted value : 40183.748620769795 real_value: 35000.0
# age: 44.0 predicted value : 143098.35194310913 real_value: 140000.0
# age: 29.0 predicted value : 46615.911328416 real_value: 40000.0
# age: 43.0 predicted value : 136666.18923546292 real_value: 170000.0
# age: 48.0 predicted value : 168827.00277369394 real_value: 180000.0
# age: 29.0 predicted value : 46615.911328416 real_value: 50000.0
# age: 31.0 predicted value : 59480.23674370843 real_value: 55000.0
# age: 52.0 predicted value : 194555.6536042788 real_value: 170000.0
# age: 29.0 predicted value : 46615.911328416 real_value: 35000.0
# age: 36.0 predicted value : 91641.05028193948 real_value: 70000.0
# age: 46.0 predicted value : 155962.67735840153 real_value: 170000.0
# age: 44.0 predicted value : 143098.35194310913 real_value: 130000.0
# age: 41.0 predicted value : 123801.86382017052 real_value: 110000.0
# age: 47.0 predicted value : 162394.84006604773 real_value: 170000.0
# age: 34.0 predicted value : 78776.72486664704 real_value: 80000.0
# age: 33.0 predicted value : 72344.56215900084 real_value: 100000.0
# age: 42.0 predicted value : 130234.02652781672 real_value: 110000.0
# age: 31.0 predicted value : 59480.23674370843 real_value: 50000.0
# age: 35.0 predicted value : 85208.88757429327 real_value: 95000.0
# age: 31.0 predicted value : 59480.23674370843 real_value: 50000.0
# age: 30.0 predicted value : 53048.07403606223 real_value: 40000.0
# age: 34.0 predicted value : 78776.72486664704 real_value: 100000.0
# age: 32.0 predicted value : 65912.39945135463 real_value: 100000.0
# age: 37.0 predicted value : 98073.21298958568 real_value: 95000.0
# age: 47.0 predicted value : 162394.84006604773 real_value: 170000.0

# %%
# plotting
plt.scatter(X_train,Y_train,color="red")
plt.plot(X_train,regressor.predict(X_train),color="blue")
plt.show()

# %%
# plotting
plt.scatter(X_test,Y_test,color="red")
plt.plot(X_train,regressor.predict(X_train),color="blue")
plt.show()
